# %% [markdown]
# <a href="https://colab.research.google.com/github/SentinelError/Workout-Data-Analysis/blob/main/WorkoutAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_excel("streak.xlsx")

# %%
data.head()
# Out:
#         Date  Total Steps
# 0 2023-01-01        16765
# 1 2023-01-02        16442
# 2 2023-01-03        15358
# 3 2023-01-04        16459
# 4 2023-01-05        15402

# %%
data.rename(columns={'Total Steps':'steps','Date':'date'},inplace=True)
data.head()
# Out:
#         date  steps
# 0 2023-01-01  16765
# 1 2023-01-02  16442
# 2 2023-01-03  15358
# 3 2023-01-04  16459
# 4 2023-01-05  15402

# %%
data.dtypes
# Out:
# date     datetime64[ns]
# steps             int64
# dtype: object

# %%
def longest_streak(steps_data, date_data):
    current_streak = 0
    longest_streak = 0
    start_date_longest = None
    end_date_longest = None
    start_date_current = None

    for i, steps in enumerate(steps_data):
      if steps >= 10000:
        current_streak += 1
        if current_streak == 1:
          start_date_current = date_data[i]
      else:
        if current_streak > longest_streak:
          longest_streak = current_streak
          start_date_longest = start_date_current
          end_date_longest = date_data[i - 1]

        current_streak = 0

## Check to see if the current streak at the end of the data is longer than the longest streak, if so, update the streak and dates.
    if current_streak > longest_streak:
          longest_streak = current_streak
          start_date_longest = start_date_current
          end_date_longest = date_data[-1]

    return longest_streak, start_date_longest, end_date_longest

steps_data = data['steps'].tolist()
date_data = data['date'].tolist()

longest_streak_count, start_date, end_date = longest_streak(steps_data, date_data)

print("Longest Streak = ", longest_streak(steps_data, date_data))
print("Start Date of Longest Streak:", start_date)
print("End Date of Longest Streak:", end_date)
# Out:
# Longest Streak =  (61, Timestamp('2023-01-01 00:00:00'), Timestamp('2023-03-02 00:00:00'))
# Start Date of Longest Streak: 2023-01-01 00:00:00
# End Date of Longest Streak: 2023-03-02 00:00:00

# %%
import pandas as pd

def longest_streak(steps_data, date_data):
    streak_info = []  # List to store streak information

    current_streak = 0
    start_date_current = None

    for i, steps in enumerate(steps_data):
        if steps >= 10000:
            current_streak += 1
            if current_streak == 1:
                start_date_current = date_data[i]
        else:
            if current_streak > 0:  # If a streak has ended
                streak_info.append({
                    'Streak': current_streak,
                    'Start Date': start_date_current,
                    'End Date': date_data[i - 1]
                })
            current_streak = 0

    # Check if the current streak at the end of the data is longer than the longest streak
    if current_streak > 0:
        streak_info.append({
            'Streak': current_streak,
            'Start Date': start_date_current,
            'End Date': date_data[-1]
        })

    # Convert streak_info list to DataFrame and sort by 'Streak'
    streak_df = pd.DataFrame(streak_info).sort_values(by='Streak', ascending=False)

    return streak_df

# Example usage
steps_data = data['steps'].tolist()
date_data = data['date'].tolist()

streak_table = longest_streak(steps_data, date_data)
print(streak_table)
# Out:
#     Streak Start Date   End Date
# 0       61 2023-01-01 2023-03-02
# 8       39 2023-04-24 2023-06-01
# 4       12 2023-03-17 2023-03-28
# 5       10 2023-03-30 2023-04-08
# 12       9 2023-06-19 2023-06-27
# 7        6 2023-04-16 2023-04-21
# 11       6 2023-06-11 2023-06-16
# 6        5 2023-04-10 2023-04-14
# 10       5 2023-06-05 2023-06-09
# 2        3 2023-03-08 2023-03-10
# 3        3 2023-03-13 2023-03-15
# 1        1 2023-03-06 2023-03-06
# 9        1 2023-06-03 2023-06-03
